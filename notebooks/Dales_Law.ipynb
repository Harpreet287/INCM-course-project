# %% [markdown]
# # Dales Law

# %%
# Cell 2 — Imports and device
import os, json, time, random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from IPython.display import display, Markdown

import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

UPLOADED_SCRIPT_PATH = "./psychrnn_perceptualdiscrimination_noise_comparison.py"
if Path(UPLOADED_SCRIPT_PATH).exists():
    display(Markdown(f"**Found uploaded script:** `{UPLOADED_SCRIPT_PATH}`"))
else:
    display(Markdown(f"**No uploaded script found at** `{UPLOADED_SCRIPT_PATH}`"))
# Out:
# Device: cpu
# **No uploaded script found at** `./psychrnn_perceptualdiscrimination_noise_comparison.py`

# %%
# Cell 4 — Utilities
def set_seed(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def savefig(fig, path, dpi=150):
    fig.savefig(path, dpi=dpi, bbox_inches='tight')
    print("Saved:", path)

# %%
# Cell 6 — Task implementation
def generate_batch(batch_size, T, coherence, stim_std=1.0, input_dim=2, device='cpu'):
    """
    Generate PerceptualDiscrimination batch.
    Each trial: choose label {0,1}; add coherence to the chosen channel across all timesteps.
    Returns:
      x: torch.Tensor (batch, T, input_dim)
      y: torch.LongTensor (batch,)
    """
    labels = np.random.choice([0,1], size=(batch_size,))
    x = np.random.randn(batch_size, T, input_dim) * stim_std
    for i, lab in enumerate(labels):
        x[i, :, lab] += coherence
    x_t = torch.tensor(x, dtype=torch.float32, device=device)
    y_t = torch.tensor(labels, dtype=torch.long, device=device)
    return x_t, y_t

# %%
# Cell 8 — Model class
class RNNWithGateDale(nn.Module):
    def __init__(self, input_dim=2, hidden_dim=128, output_dim=2,
                 rec_noise_std=0.0, gate=True, dale=True, dale_exc_frac=0.8, device='cpu'):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.rec_noise_std = rec_noise_std
        self.gate = gate
        self.dale = dale
        self.device = device

        # input linear as parameters for faster custom compute
        self.W_in = nn.Parameter(torch.randn(hidden_dim, input_dim) * (1.0/np.sqrt(input_dim)))
        self.b_in = nn.Parameter(torch.zeros(hidden_dim))

        # recurrent raw weights; we will enforce Dale's law via transformation
        self.W_rec_raw = nn.Parameter(torch.randn(hidden_dim, hidden_dim) * (1.0/np.sqrt(hidden_dim)))
        self.b_rec = nn.Parameter(torch.zeros(hidden_dim))

        # output layer
        self.W_out = nn.Linear(hidden_dim, output_dim)

        # gating params
        if self.gate:
            self.W_gate = nn.Parameter(torch.randn(hidden_dim, input_dim) * (1.0/np.sqrt(input_dim)))
            self.b_gate = nn.Parameter(torch.zeros(hidden_dim))

        # dale sign buffer
        if self.dale:
            n_exc = int(round(dale_exc_frac * hidden_dim))
            signs = np.array([1]*n_exc + [-1]*(hidden_dim-n_exc))
            np.random.shuffle(signs)
            self.register_buffer('dale_sign', torch.tensor(signs, dtype=torch.float32).to(device))
        else:
            self.register_buffer('dale_sign', torch.ones(hidden_dim, dtype=torch.float32).to(device))

        self.activation = torch.tanh

    def effective_Wrec(self):
        # make columns non-negative then multiply by sign
        W_abs = torch.abs(self.W_rec_raw)  # all >=0
        # apply sign along columns (outgoing weights)
        W = W_abs * self.dale_sign.unsqueeze(0)
        return W

    def forward(self, x, return_hidden=False):
        # x: (batch, T, input_dim)
        batch, T, _ = x.size()
        h = torch.zeros(batch, self.hidden_dim, device=x.device)
        hs = []
        W_rec = self.effective_Wrec()
        for t in range(T):
            xt = x[:, t, :]  # (batch, input_dim)
            inp = torch.matmul(xt, self.W_in.t()) + self.b_in  # (batch, hidden)
            if self.gate:
                g = torch.sigmoid(torch.matmul(xt, self.W_gate.t()) + self.b_gate)  # (batch, hidden)
                inp = inp * g
            rec = torch.matmul(h, W_rec.t()) + self.b_rec  # (batch, hidden)
            h = self.activation(inp + rec)
            if self.rec_noise_std and self.training:
                h = h + torch.randn_like(h) * float(self.rec_noise_std)
            hs.append(h.unsqueeze(1))
        hs = torch.cat(hs, dim=1)  # (batch, T, hidden)
        logits = self.W_out(hs[:, -1, :])  # last timestep decision
        if return_hidden:
            return logits, hs
        return logits

# %%
# Cell 10 — Evaluation functions
import torch.nn.functional as F

def compute_accuracy(model, coherence, n_trials=512, batch_size=128, T=40, stim_std=1.0, device='cpu'):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        while total < n_trials:
            b = min(batch_size, n_trials - total)
            x, y = generate_batch(b, T, coherence, stim_std=stim_std, device=device)
            logits = model(x)
            preds = logits.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += b
    return correct / total

def psychometric_curve(model, coherences, n_trials_each=600, batch_size=128, T=40, stim_std=1.0, device='cpu'):
    accs = []
    for c in coherences:
        acc = compute_accuracy(model, c, n_trials=n_trials_each, batch_size=batch_size, T=T, stim_std=stim_std, device=device)
        accs.append(acc)
    return np.array(accs)

def fit_consistent_pca(models, names, coherence=0.4, T=40, trials_per_model=12, device='cpu'):
    """
    Fit PCA on a pooled set of hidden-states across models/trials to ensure consistent projection.
    Returns fitted PCA object.
    """
    all_h = []
    with torch.no_grad():
        for name, model in zip(names, models):
            model.eval()
            for _ in range(trials_per_model):
                x, y = generate_batch(1, T, coherence, device=device)
                _, hs = model(x, return_hidden=True)
                all_h.append(hs[0].cpu().numpy())  # (T, hidden)
    all_h_concat = np.concatenate(all_h, axis=0)  # (trials*T, hidden)
    pca = PCA(n_components=3)
    pca.fit(all_h_concat)
    return pca

def pca_traj_in_pca(model, pca, coherence=0.4, T=40, device='cpu'):
    model.eval()
    with torch.no_grad():
        x, y = generate_batch(1, T, coherence, device=device)
        _, hs = model(x, return_hidden=True)
        h = hs[0].cpu().numpy()  # T x hidden
    traj = pca.transform(h)  # T x 3
    return traj, int(y.cpu().numpy()[0]), traj

# %%
# Cell 12 — Training function
def train_model(
    seed=0,
    training_iters=20000,
    batch_size=128,
    T=40,
    hidden_dim=128,
    lr=3e-4,
    rec_noise=0.0,
    gate=True,
    dale=True,
    dale_exc_frac=0.8,
    start_coh=0.6,
    min_coh=0.1,
    coh_step=0.1,
    mode='baseline',   # 'baseline' or 'curriculum'
    eval_interval=500,
    target_acc=0.85,
    outdir='out_run',
    device='cpu',
    verbose=True
):
    set_seed(seed)
    os.makedirs(outdir, exist_ok=True)

    model = RNNWithGateDale(input_dim=2, hidden_dim=hidden_dim, output_dim=2,
                            rec_noise_std=rec_noise, gate=gate, dale=dale,
                            dale_exc_frac=dale_exc_frac, device=device).to(device)
    opt = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()

    losses = []
    psych_history = []
    eval_coherences = [0.05, 0.1, 0.2, 0.4, 0.6, 0.8]
    coher = float(start_coh)

    it = 0
    while it < training_iters:
        model.train()
        x, y = generate_batch(batch_size, T, coher, device=device)
        opt.zero_grad()
        logits = model(x)
        loss = loss_fn(logits, y)
        loss.backward()
        opt.step()
        losses.append(float(loss.item()))
        it += 1

        if it % eval_interval == 0:
            val_acc = compute_accuracy(model, coher, n_trials=512, batch_size=batch_size, T=T, device=device)
            psych = psychometric_curve(model, eval_coherences, n_trials_each=300, batch_size=batch_size, T=T, device=device)
            psych_history.append({"iter": int(it), "coherence": float(coher), "val_acc": float(val_acc), "psych": psych.tolist()})
            if verbose:
                print(f"[{outdir}] iter {it} | coh {coher:.2f} | loss {loss.item():.4f} | val_acc {val_acc:.3f}")
            # curriculum step
            if mode == 'curriculum' and val_acc >= target_acc and (coher - coh_step) >= min_coh:
                coher = max(min_coh, coher - coh_step)
                if verbose:
                    print(f"  -> Curriculum: lowered coherence to {coher:.2f} at iter {it}")

    final_psych = psychometric_curve(model, eval_coherences, n_trials_each=600, batch_size=batch_size, T=T, device=device)

    torch.save(model.state_dict(), os.path.join(outdir, 'model_state.pt'))

    results = {
        "losses": list(map(float, losses)),
        "psych_history": psych_history,
        "final_psych": list(map(float, final_psych)),
        "eval_coherences": list(map(float, eval_coherences)),
        "params": {
            "seed": int(seed), "training_iters": int(training_iters), "batch_size": int(batch_size),
            "T": int(T), "hidden_dim": int(hidden_dim), "lr": float(lr),
            "rec_noise": float(rec_noise), "gate": bool(gate), "dale": bool(dale),
            "start_coh": float(start_coh), "min_coh": float(min_coh), "coh_step": float(coh_step),
            "mode": mode
        }
    }
    with open(os.path.join(outdir, 'results.json'), 'w') as f:
        json.dump(results, f, indent=2)
    return model, results

# %%
HIDDEN_DIM = 128         # model size
TRAIN_ITERS = 10000      # recommended for final; set 2000-5000 for quick demo
BATCH_SIZE = 128
T = 40
LR = 3e-4
REC_NOISE_NOISY = 0.1
SEED = 0
DEVICE = device

OUT_ROOT = Path("out_full_experiment")
OUT_ROOT.mkdir(exist_ok=True)

# If you want a fast demo locally (comment/uncomment):
# TRAIN_ITERS = 2000

# %%
experiments = {
    "baseline": {"rec_noise": 0.0, "start_coh": 0.2, "mode": "baseline"},
    "noisy":    {"rec_noise": REC_NOISE_NOISY, "start_coh": 0.2, "mode": "baseline"},
    "curriculum":{"rec_noise": 0.0, "start_coh": 0.8, "mode": "curriculum"}
}

models = {}
results = {}

for name, cfg in experiments.items():
    outdir = str(OUT_ROOT / name)
    print("\n=== RUN:", name, "->", outdir)
    model, res = train_model(
        seed=SEED,
        training_iters=TRAIN_ITERS,
        batch_size=BATCH_SIZE,
        T=T,
        hidden_dim=HIDDEN_DIM,
        lr=LR,
        rec_noise=cfg["rec_noise"],
        gate=True,                       # FULL version: gating ON
        dale=True,                       # FULL version: Dale's law ON
        dale_exc_frac=0.8,
        start_coh=cfg["start_coh"],
        min_coh=0.1,
        coh_step=0.1,
        mode=cfg["mode"],
        eval_interval=200,
        target_acc=0.88,
        outdir=outdir,
        device=DEVICE,
        verbose=True
    )
    models[name] = model
    results[name] = res
    print("Saved results for", name, "->", outdir)
# Out:
# === RUN: baseline -> out_full_experiment/baseline
# [out_full_experiment/baseline] iter 200 | coh 0.20 | loss 0.6630 | val_acc 0.621
# [out_full_experiment/baseline] iter 400 | coh 0.20 | loss 0.7228 | val_acc 0.525
# [out_full_experiment/baseline] iter 600 | coh 0.20 | loss 0.6247 | val_acc 0.703
# [out_full_experiment/baseline] iter 800 | coh 0.20 | loss 0.6870 | val_acc 0.602
# [out_full_experiment/baseline] iter 1000 | coh 0.20 | loss 0.6721 | val_acc 0.580
# [out_full_experiment/baseline] iter 1200 | coh 0.20 | loss 0.6701 | val_acc 0.572
# [out_full_experiment/baseline] iter 1400 | coh 0.20 | loss 0.6599 | val_acc 0.596
# [out_full_experiment/baseline] iter 1600 | coh 0.20 | loss 0.6596 | val_acc 0.631
# [out_full_experiment/baseline] iter 1800 | coh 0.20 | loss 0.6858 | val_acc 0.561
# [out_full_experiment/baseline] iter 2000 | coh 0.20 | loss 0.6777 | val_acc 0.557
# [out_full_experiment/baseline] iter 2200 | coh 0.20 | loss 0.6720 | val_acc 0.574
# [out_full_experiment/baseline] iter 2400 | coh 0.20 | loss 0.6858 | val_acc 0.594
# [out_full_experiment/baseline] iter 2600 | coh 0.20 | loss 0.6965 | val_acc 0.613
# [out_full_experiment/baseline] iter 2800 | coh 0.20 | loss 0.6561 | val_acc 0.594
# [out_full_experiment/baseline] iter 3000 | coh 0.20 | loss 0.6673 | val_acc 0.621
# [out_full_experiment/baseline] iter 3200 | coh 0.20 | loss 0.6396 | val_acc 0.625
# [out_full_experiment/baseline] iter 3400 | coh 0.20 | loss 0.6386 | val_acc 0.668
# [out_full_experiment/baseline] iter 3600 | coh 0.20 | loss 0.6316 | val_acc 0.596
# [out_full_experiment/baseline] iter 3800 | coh 0.20 | loss 0.6583 | val_acc 0.629
# [out_full_experiment/baseline] iter 4000 | coh 0.20 | loss 0.6089 | val_acc 0.627
# [out_full_experiment/baseline] iter 4200 | coh 0.20 | loss 0.6712 | val_acc 0.598
# [out_full_experiment/baseline] iter 4400 | coh 0.20 | loss 0.7233 | val_acc 0.584
# [out_full_experiment/baseline] iter 4600 | coh 0.20 | loss 0.6411 | val_acc 0.646
# [out_full_experiment/baseline] iter 4800 | coh 0.20 | loss 0.6486 | val_acc 0.615
# [out_full_experiment/baseline] iter 5000 | coh 0.20 | loss 0.6167 | val_acc 0.619
# [out_full_experiment/baseline] iter 5200 | coh 0.20 | loss 0.5828 | val_acc 0.621
# [out_full_experiment/baseline] iter 5400 | coh 0.20 | loss 0.6316 | val_acc 0.635
# [out_full_experiment/baseline] iter 5600 | coh 0.20 | loss 0.6925 | val_acc 0.639
# [out_full_experiment/baseline] iter 5800 | coh 0.20 | loss 0.6057 | val_acc 0.666
# [out_full_experiment/baseline] iter 6000 | coh 0.20 | loss 0.6554 | val_acc 0.598
# [out_full_experiment/baseline] iter 6200 | coh 0.20 | loss 0.6599 | val_acc 0.619
# [out_full_experiment/baseline] iter 6400 | coh 0.20 | loss 0.6834 | val_acc 0.574
# [out_full_experiment/baseline] iter 6600 | coh 0.20 | loss 0.6873 | val_acc 0.568
# [out_full_experiment/baseline] iter 6800 | coh 0.20 | loss 0.5217 | val_acc 0.658
# [out_full_experiment/baseline] iter 7000 | coh 0.20 | loss 0.5233 | val_acc 0.744
# [out_full_experiment/baseline] iter 7200 | coh 0.20 | loss 0.5603 | val_acc 0.758
# [out_full_experiment/baseline] iter 7400 | coh 0.20 | loss 0.6027 | val_acc 0.768
# [out_full_experiment/baseline] iter 7600 | coh 0.20 | loss 0.5564 | val_acc 0.742
# [out_full_experiment/baseline] iter 7800 | coh 0.20 | loss 0.5472 | val_acc 0.773
# [out_full_experiment/baseline] iter 8000 | coh 0.20 | loss 0.5247 | val_acc 0.768
# [out_full_experiment/baseline] iter 8200 | coh 0.20 | loss 0.4575 | val_acc 0.814
# [out_full_experiment/baseline] iter 8400 | coh 0.20 | loss 0.4069 | val_acc 0.828
# [out_full_experiment/baseline] iter 8600 | coh 0.20 | loss 0.5057 | val_acc 0.789
# [out_full_experiment/baseline] iter 8800 | coh 0.20 | loss 0.5053 | val_acc 0.783
# [out_full_experiment/baseline] iter 9000 | coh 0.20 | loss 0.5078 | val_acc 0.793
# [out_full_experiment/baseline] iter 9200 | coh 0.20 | loss 0.4832 | val_acc 0.787
# [out_full_experiment/baseline] iter 9400 | coh 0.20 | loss 0.4971 | val_acc 0.781
# [out_full_experiment/baseline] iter 9600 | coh 0.20 | loss 0.6502 | val_acc 0.697
# [out_full_experiment/baseline] iter 9800 | coh 0.20 | loss 0.6929 | val_acc 0.555
# [out_full_experiment/baseline] iter 10000 | coh 0.20 | loss 0.6801 | val_acc 0.541
# Saved results for baseline -> out_full_experiment/baseline
#
# === RUN: noisy -> out_full_experiment/noisy
# [out_full_experiment/noisy] iter 200 | coh 0.20 | loss 0.6710 | val_acc 0.527
# [out_full_experiment/noisy] iter 400 | coh 0.20 | loss 0.5680 | val_acc 0.730
# [out_full_experiment/noisy] iter 600 | coh 0.20 | loss 0.6865 | val_acc 0.594
# [out_full_experiment/noisy] iter 800 | coh 0.20 | loss 0.6899 | val_acc 0.588
# [out_full_experiment/noisy] iter 1000 | coh 0.20 | loss 0.5834 | val_acc 0.615
# [out_full_experiment/noisy] iter 1200 | coh 0.20 | loss 0.6694 | val_acc 0.576
# [out_full_experiment/noisy] iter 1400 | coh 0.20 | loss 0.6102 | val_acc 0.648
# [out_full_experiment/noisy] iter 1600 | coh 0.20 | loss 0.5506 | val_acc 0.723
# [out_full_experiment/noisy] iter 1800 | coh 0.20 | loss 0.6626 | val_acc 0.643
# [out_full_experiment/noisy] iter 2000 | coh 0.20 | loss 0.5779 | val_acc 0.766
# [out_full_experiment/noisy] iter 2200 | coh 0.20 | loss 0.4406 | val_acc 0.760
# [out_full_experiment/noisy] iter 2400 | coh 0.20 | loss 0.6565 | val_acc 0.650
# [out_full_experiment/noisy] iter 2600 | coh 0.20 | loss 0.4859 | val_acc 0.756
# [out_full_experiment/noisy] iter 2800 | coh 0.20 | loss 0.5457 | val_acc 0.732
# [out_full_experiment/noisy] iter 3000 | coh 0.20 | loss 0.5466 | val_acc 0.756
# [out_full_experiment/noisy] iter 3200 | coh 0.20 | loss 0.4126 | val_acc 0.805
# [out_full_experiment/noisy] iter 3400 | coh 0.20 | loss 0.5512 | val_acc 0.762
# [out_full_experiment/noisy] iter 3600 | coh 0.20 | loss 0.4659 | val_acc 0.771
# [out_full_experiment/noisy] iter 3800 | coh 0.20 | loss 0.5438 | val_acc 0.801
# [out_full_experiment/noisy] iter 4000 | coh 0.20 | loss 0.5110 | val_acc 0.789
# [out_full_experiment/noisy] iter 4200 | coh 0.20 | loss 0.4929 | val_acc 0.789
# [out_full_experiment/noisy] iter 4400 | coh 0.20 | loss 0.4455 | val_acc 0.773
# [out_full_experiment/noisy] iter 4600 | coh 0.20 | loss 0.4398 | val_acc 0.787
# [out_full_experiment/noisy] iter 4800 | coh 0.20 | loss 0.3982 | val_acc 0.799
# [out_full_experiment/noisy] iter 5000 | coh 0.20 | loss 0.3205 | val_acc 0.795
# [out_full_experiment/noisy] iter 5200 | coh 0.20 | loss 0.4269 | val_acc 0.775
# [out_full_experiment/noisy] iter 5400 | coh 0.20 | loss 0.4825 | val_acc 0.805
# [out_full_experiment/noisy] iter 5600 | coh 0.20 | loss 0.4535 | val_acc 0.797
# [out_full_experiment/noisy] iter 5800 | coh 0.20 | loss 0.4823 | val_acc 0.787
# [out_full_experiment/noisy] iter 6000 | coh 0.20 | loss 0.4777 | val_acc 0.820
# [out_full_experiment/noisy] iter 6200 | coh 0.20 | loss 0.4703 | val_acc 0.816
# [out_full_experiment/noisy] iter 6400 | coh 0.20 | loss 0.5098 | val_acc 0.764
# [out_full_experiment/noisy] iter 6600 | coh 0.20 | loss 0.4636 | val_acc 0.797
# [out_full_experiment/noisy] iter 6800 | coh 0.20 | loss 0.3971 | val_acc 0.756
# [out_full_experiment/noisy] iter 7000 | coh 0.20 | loss 0.4192 | val_acc 0.801
# [out_full_experiment/noisy] iter 7200 | coh 0.20 | loss 0.5524 | val_acc 0.787
# [out_full_experiment/noisy] iter 7400 | coh 0.20 | loss 0.5018 | val_acc 0.805
# [out_full_experiment/noisy] iter 7600 | coh 0.20 | loss 0.5054 | val_acc 0.783
# [out_full_experiment/noisy] iter 7800 | coh 0.20 | loss 0.4509 | val_acc 0.789
# [out_full_experiment/noisy] iter 8000 | coh 0.20 | loss 0.5396 | val_acc 0.793
# [out_full_experiment/noisy] iter 8200 | coh 0.20 | loss 0.4080 | val_acc 0.801
# [out_full_experiment/noisy] iter 8400 | coh 0.20 | loss 0.4518 | val_acc 0.822
# [out_full_experiment/noisy] iter 8600 | coh 0.20 | loss 0.4931 | val_acc 0.758
# [out_full_experiment/noisy] iter 8800 | coh 0.20 | loss 0.4600 | val_acc 0.764
# [out_full_experiment/noisy] iter 9000 | coh 0.20 | loss 0.4739 | val_acc 0.783
# [out_full_experiment/noisy] iter 9200 | coh 0.20 | loss 0.4895 | val_acc 0.758
# [out_full_experiment/noisy] iter 9400 | coh 0.20 | loss 0.4920 | val_acc 0.785
# [out_full_experiment/noisy] iter 9600 | coh 0.20 | loss 0.4625 | val_acc 0.818
# [out_full_experiment/noisy] iter 9800 | coh 0.20 | loss 0.7077 | val_acc 0.627
# [out_full_experiment/noisy] iter 10000 | coh 0.20 | loss 0.6701 | val_acc 0.605
# Saved results for noisy -> out_full_experiment/noisy
#
# === RUN: curriculum -> out_full_experiment/curriculum
# [out_full_experiment/curriculum] iter 200 | coh 0.80 | loss 0.4794 | val_acc 0.754
# [out_full_experiment/curriculum] iter 400 | coh 0.80 | loss 0.8661 | val_acc 0.689
# [out_full_experiment/curriculum] iter 600 | coh 0.80 | loss 0.4123 | val_acc 0.770
# [out_full_experiment/curriculum] iter 800 | coh 0.80 | loss 0.4921 | val_acc 0.795
# [out_full_experiment/curriculum] iter 1000 | coh 0.80 | loss 0.3775 | val_acc 0.805
# [out_full_experiment/curriculum] iter 1200 | coh 0.80 | loss 0.1164 | val_acc 0.949
#   -> Curriculum: lowered coherence to 0.70 at iter 1200
# [out_full_experiment/curriculum] iter 1400 | coh 0.70 | loss 0.0880 | val_acc 0.975
#   -> Curriculum: lowered coherence to 0.60 at iter 1400
# [out_full_experiment/curriculum] iter 1600 | coh 0.60 | loss 0.5537 | val_acc 0.721
# [out_full_experiment/curriculum] iter 1800 | coh 0.60 | loss 0.2186 | val_acc 0.953
#   -> Curriculum: lowered coherence to 0.50 at iter 1800
# [out_full_experiment/curriculum] iter 2000 | coh 0.50 | loss 0.2789 | val_acc 0.893
#   -> Curriculum: lowered coherence to 0.40 at iter 2000
# [out_full_experiment/curriculum] iter 2200 | coh 0.40 | loss 0.2628 | val_acc 0.883
#   -> Curriculum: lowered coherence to 0.30 at iter 2200
# [out_full_experiment/curriculum] iter 2400 | coh 0.30 | loss 0.5584 | val_acc 0.684
# [out_full_experiment/curriculum] iter 2600 | coh 0.30 | loss 0.4022 | val_acc 0.824
# [out_full_experiment/curriculum] iter 2800 | coh 0.30 | loss 0.4403 | val_acc 0.812
# [out_full_experiment/curriculum] iter 3000 | coh 0.30 | loss 0.4091 | val_acc 0.844
# [out_full_experiment/curriculum] iter 3200 | coh 0.30 | loss 0.2957 | val_acc 0.867
# [out_full_experiment/curriculum] iter 3400 | coh 0.30 | loss 0.3567 | val_acc 0.822
# [out_full_experiment/curriculum] iter 3600 | coh 0.30 | loss 0.3555 | val_acc 0.846
# [out_full_experiment/curriculum] iter 3800 | coh 0.30 | loss 0.3540 | val_acc 0.869
# [out_full_experiment/curriculum] iter 4000 | coh 0.30 | loss 0.3627 | val_acc 0.865
# [out_full_experiment/curriculum] iter 4200 | coh 0.30 | loss 0.3866 | val_acc 0.854
# [out_full_experiment/curriculum] iter 4400 | coh 0.30 | loss 0.3359 | val_acc 0.854
# [out_full_experiment/curriculum] iter 4600 | coh 0.30 | loss 0.3266 | val_acc 0.873
# [out_full_experiment/curriculum] iter 4800 | coh 0.30 | loss 0.2709 | val_acc 0.883
#   -> Curriculum: lowered coherence to 0.20 at iter 4800
# [out_full_experiment/curriculum] iter 5000 | coh 0.20 | loss 0.3797 | val_acc 0.779
# [out_full_experiment/curriculum] iter 5200 | coh 0.20 | loss 0.4202 | val_acc 0.779
# [out_full_experiment/curriculum] iter 5400 | coh 0.20 | loss 0.5170 | val_acc 0.801
# [out_full_experiment/curriculum] iter 5600 | coh 0.20 | loss 0.5080 | val_acc 0.805
# [out_full_experiment/curriculum] iter 5800 | coh 0.20 | loss 0.4669 | val_acc 0.779
# [out_full_experiment/curriculum] iter 6000 | coh 0.20 | loss 0.4678 | val_acc 0.803
# [out_full_experiment/curriculum] iter 6200 | coh 0.20 | loss 0.4739 | val_acc 0.789
# [out_full_experiment/curriculum] iter 6400 | coh 0.20 | loss 0.5078 | val_acc 0.758
# [out_full_experiment/curriculum] iter 6600 | coh 0.20 | loss 0.4646 | val_acc 0.791
# [out_full_experiment/curriculum] iter 6800 | coh 0.20 | loss 0.3939 | val_acc 0.744
# [out_full_experiment/curriculum] iter 7000 | coh 0.20 | loss 0.4965 | val_acc 0.797
# [out_full_experiment/curriculum] iter 7200 | coh 0.20 | loss 0.4709 | val_acc 0.803
# [out_full_experiment/curriculum] iter 7400 | coh 0.20 | loss 0.5185 | val_acc 0.783
# [out_full_experiment/curriculum] iter 7600 | coh 0.20 | loss 0.4557 | val_acc 0.816
# [out_full_experiment/curriculum] iter 7800 | coh 0.20 | loss 0.4466 | val_acc 0.787
# [out_full_experiment/curriculum] iter 8000 | coh 0.20 | loss 0.5418 | val_acc 0.760
# [out_full_experiment/curriculum] iter 8200 | coh 0.20 | loss 0.4682 | val_acc 0.807
# [out_full_experiment/curriculum] iter 8400 | coh 0.20 | loss 0.4273 | val_acc 0.824
# [out_full_experiment/curriculum] iter 8600 | coh 0.20 | loss 0.4744 | val_acc 0.783
# [out_full_experiment/curriculum] iter 8800 | coh 0.20 | loss 0.5115 | val_acc 0.734
# [out_full_experiment/curriculum] iter 9000 | coh 0.20 | loss 0.4843 | val_acc 0.795
# [out_full_experiment/curriculum] iter 9200 | coh 0.20 | loss 0.4997 | val_acc 0.762
# [out_full_experiment/curriculum] iter 9400 | coh 0.20 | loss 0.4654 | val_acc 0.779
# [out_full_experiment/curriculum] iter 9600 | coh 0.20 | loss 0.4753 | val_acc 0.803
# [out_full_experiment/curriculum] iter 9800 | coh 0.20 | loss 0.4898 | val_acc 0.787
# [out_full_experiment/curriculum] iter 10000 | coh 0.20 | loss 0.4804 | val_acc 0.789
# Saved results for curriculum -> out_full_experiment/curriculum

# %%
# # Cell 15 — run the three main experiments (this may take a while on CPU)
# experiments = {
#     # "baseline": {"rec_noise": 0.0, "start_coh": 0.2, "mode": "baseline"},
#     # "noisy":    {"rec_noise": REC_NOISE_NOISY, "start_coh": 0.2, "mode": "baseline"},
#     "curriculum":{"rec_noise": 0.0, "start_coh": 0.8, "mode": "curriculum"}
# }

# # models = {}
# # results = {}

# for name, cfg in experiments.items():
#     outdir = str(OUT_ROOT / name)
#     print("\n=== RUN:", name, "->", outdir)
#     model, res = train_model(
#         seed=SEED,
#         training_iters=TRAIN_ITERS/2,
#         batch_size=BATCH_SIZE,
#         T=T,
#         hidden_dim=HIDDEN_DIM,
#         lr=LR,
#         rec_noise=cfg["rec_noise"],
#         gate=True,                       # FULL version: gating ON
#         dale=True,                       # FULL version: Dale's law ON
#         dale_exc_frac=0.8,
#         start_coh=cfg["start_coh"],
#         min_coh=0.1,
#         coh_step=0.05,
#         mode=cfg["mode"],
#         eval_interval=500,
#         target_acc=0.88,
#         outdir=outdir,
#         device=DEVICE,
#         verbose=True
#     )
#     models[name] = model
#     results[name] = res
#     print("Saved results for", name, "->", outdir)

# %%
# Cell 17 — Plot training losses and psychometric curves
def plot_loss_curves(results_dict, outpath):
    plt.figure(figsize=(9,4))
    for name, res in results_dict.items():
        losses = np.array(res["losses"])
        if len(losses) > 20:
            smooth = np.convolve(losses, np.ones(20)/20, mode='same')
        else:
            smooth = losses
        plt.plot(smooth, label=name)
    plt.xlabel("Iteration"); plt.ylabel("Loss (smoothed)"); plt.title("Training Loss (smoothed)")
    plt.legend()
    savefig(plt, outpath)

def plot_psychcurves(results_dict, outpath):
    plt.figure(figsize=(6,4))
    for name, res in results_dict.items():
        coh = np.array(res["eval_coherences"])
        psych = np.array(res["final_psych"])
        plt.plot(coh, psych, '-o', label=name)
    plt.xlabel("Coherence"); plt.ylabel("Proportion correct"); plt.title("Psychometric Curves")
    plt.legend()
    savefig(plt, outpath)

plot_loss_curves(results, OUT_ROOT / "loss_curves.png")
plot_psychcurves(results, OUT_ROOT / "psych_curves.png")
# Out:
# Saved: out_full_experiment/loss_curves.png
# Saved: out_full_experiment/psych_curves.png

# %%
# Cell 19 — PCA analysis and plotting
pca = fit_consistent_pca(list(models.values()), list(models.keys()), coherence=0.4, T=T, trials_per_model=12, device=DEVICE)

plt.figure(figsize=(12,4))
for i, name in enumerate(models.keys()):
    traj, label, _ = pca_traj_in_pca(models[name], pca, coherence=0.4, T=T, device=DEVICE)
    ax = plt.subplot(1, len(models), i+1)
    ax.plot(traj[:,0], traj[:,1], '-o', markersize=3)
    ax.set_title(f"{name}\nlabel={label}")
    ax.set_xlabel("PC1"); ax.set_ylabel("PC2")
plt.tight_layout()
savefig(plt, OUT_ROOT / "pca_trajectories.png")
plt.show()
# Out:
# Saved: out_full_experiment/pca_trajectories.png

# %%
# Cell 21 — Save summary
summary_lines = []
for name, res in results.items():
    final_psych = np.array(res["final_psych"])
    coh = np.array(res["eval_coherences"])
    idx = np.where(final_psych >= 0.75)[0]
    thr = float(coh[idx[0]]) if len(idx)>0 else float('nan')
    summary_lines.append(f"{name}: threshold_75 = {thr}, final_psych = {np.round(final_psych,3).tolist()}")

summary_text = "\n".join(summary_lines)
print(summary_text)
(OUT_ROOT / "results_summary.txt").write_text(summary_text)

# Save parameters and runtimes
meta = {
    "experiments": {k: v["params"] if "params" in v else results[k]["params"] for k,v in results.items()},
    "seed": SEED,
    "device": str(DEVICE)
}
with open(OUT_ROOT / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
print("Saved summary and meta to", OUT_ROOT)
# Out:
# baseline: threshold_75 = nan, final_psych = [0.525, 0.498, 0.593, 0.652, 0.722, 0.748]
# noisy: threshold_75 = 0.6, final_psych = [0.555, 0.538, 0.633, 0.7, 0.785, 0.793]
# curriculum: threshold_75 = 0.2, final_psych = [0.592, 0.612, 0.777, 0.95, 0.99, 1.0]
# Saved summary and meta to out_full_experiment

# %%
# !zip -r ./Dales_Law.zip ./out_full_experiment/
# Out:
#   adding: out_full_experiment/ (stored 0%)
#   adding: out_full_experiment/meta.json (deflated 79%)
#   adding: out_full_experiment/noisy/ (stored 0%)
#   adding: out_full_experiment/noisy/model_state.pt (deflated 10%)
#   adding: out_full_experiment/noisy/results.json (deflated 65%)
#   adding: out_full_experiment/pca_trajectories.png (deflated 7%)
#   adding: out_full_experiment/loss_curves.png (deflated 4%)
#   adding: out_full_experiment/psych_curves.png (deflated 6%)
#   adding: out_full_experiment/results_summary.txt (deflated 45%)
#   adding: out_full_experiment/curriculum/ (stored 0%)
#   adding: out_full_experiment/curriculum/model_state.pt (deflated 10%)
#   adding: out_full_experiment/curriculum/results.json (deflated 64%)
#   adding: out_full_experiment/baseline/ (stored 0%)
#   adding: out_full_experiment/baseline/model_state.pt (deflated 10%)
#   adding: out_full_experiment/baseline/results.json (deflated 65%)
